# %%
import pandas as pd
from astropy.io import ascii
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **.dat to .csv Convertion**

# %%
data_path = '../data/table1.dat'

colspecs = [
    (0, 19),    # ID
    (20, 28),   # RAdeg
    (29, 37),   # DEdeg
    (38, 43),   # e_RAdeg
    (44, 49),   # e_DEdeg
    (50, 58),   # RApeak
    (59, 67),   # DEpeak
    (68, 77),   # Sint
    (78, 85),   # e_Sint
    (86, 95),   # Speak
    (96, 103),  # e_Speak
    (104, 111), # rmspeak
    (112, 119), # e_rmspeak
    (120, 126), # thetamaj
    (127, 132), # thetamin
    (133, 139), # PA
    (140, 145), # alpha
    (146, 150), # e_alpha
    (151, 170), # ID2
    (171, 190), # ID3
]

columns = [
    "ID", "RAdeg", "DEdeg", "e_RAdeg", "e_DEdeg", "RApeak", "DEpeak", "Sint", "e_Sint",
    "Speak", "e_Speak", "rmspeak", "e_rmspeak", "thetamaj", "thetamin", "PA", "alpha",
    "e_alpha", "ID2", "ID3"
]


df = pd.read_fwf(data_path, colspecs=colspecs, names=columns)

for c in ["ID", "ID2", "ID3"]:
    df[c] = df[c].str.strip()

df.to_csv('../data/table1.csv', index=False)

# %%
df = pd.read_csv('../data/table1.csv')

# %%
print(df.shape)
# Out:
# (5762, 20)

# %%
print(df.columns)
# Out:
# Index(['ID', 'RAdeg', 'DEdeg', 'e_RAdeg', 'e_DEdeg', 'RApeak', 'DEpeak',
#        'Sint', 'e_Sint', 'Speak', 'e_Speak', 'rmspeak', 'e_rmspeak',
#        'thetamaj', 'thetamin', 'PA', 'alpha', 'e_alpha', 'ID2', 'ID3'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# ID            object
# RAdeg        float64
# DEdeg        float64
# e_RAdeg      float64
# e_DEdeg      float64
# RApeak       float64
# DEpeak       float64
# Sint         float64
# e_Sint       float64
# Speak        float64
# e_Speak      float64
# rmspeak      float64
# e_rmspeak    float64
# thetamaj     float64
# thetamin     float64
# PA           float64
# alpha        float64
# e_alpha      float64
# ID2           object
# ID3           object
# dtype: object

# %%
print(df.head())
# Out:
#                     ID     RAdeg    DEdeg  e_RAdeg  e_DEdeg    RApeak  \
# 0  J022143.11-041344.6  35.42963 -4.22905     2.59     2.65  35.43002
# 1  J022255.74-051817.5  35.73225 -5.30485     2.29     2.07  35.73219
# 2  J022632.54-051328.8  36.63557 -5.22467     2.13     1.98  36.63563
# 3  J022915.86-044216.7  37.31609 -4.70464     3.94     3.38  37.31561
# 4  J021640.74-044404.4  34.16974 -4.73456     2.06     2.08  34.16980
#
#     DEpeak       Sint   e_Sint      Speak  e_Speak  rmspeak  e_rmspeak  \
# 0 -4.22940  469.39263  0.01424  301.11002  0.00914  0.02774    0.02761
# 1 -5.30480  269.69099  0.01880  232.57525  0.01621  0.02984    0.02973
# 2 -5.22469   71.48008  0.00953   68.15745  0.00909  0.01850    0.01847
# 3 -4.70498  272.04369  0.04092  153.31504  0.02306  0.05453    0.05453
# 4 -4.73445   60.58129  0.00945   52.00014  0.00811  0.02091    0.02088
#
#    thetamaj  thetamin      PA  alpha  e_alpha  ID2  ID3
# 0     24.06     14.99  136.56  -0.62     0.16  NaN  NaN
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5762 entries, 0 to 5761
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         5762 non-null   object
#  1   RAdeg      5762 non-null   float64
#  2   DEdeg      5762 non-null   float64
#  3   e_RAdeg    5762 non-null   float64
#  4   e_DEdeg    5762 non-null   float64
#  5   RApeak     5762 non-null   float64
#  6   DEpeak     5762 non-null   float64
#  7   Sint       5762 non-null   float64
#  8   e_Sint     5762 non-null   float64
#  9   Speak      5762 non-null   float64
#  10  e_Speak    5762 non-null   float64
#  11  rmspeak    5762 non-null   float64
#  12  e_rmspeak  5762 non-null   float64
#  13  thetamaj   5762 non-null   float64
#  14  thetamin   5762 non-null   float64
#  15  PA         5762 non-null   float64
#  16  alpha      3458 non-null   float64
#  17  e_alpha    3458 non-null   float64
#  18  ID2        30 non-null     object
# ...

# %%
print(df.describe())
# Out:
#              RAdeg        DEdeg      e_RAdeg      e_DEdeg       RApeak  \
# count  5762.000000  5762.000000  5762.000000  5762.000000  5762.000000
# mean     35.560395    -4.702618     2.197536     2.182966    35.560394
# std       1.016150     0.461173     1.076360     1.110192     1.016153
# min      33.477540    -5.724840     0.750000     0.950000    33.477460
# 25%      34.717712    -5.085558     1.690000     1.660000    34.717768
# 50%      35.607725    -4.652255     1.970000     1.950000    35.607985
# 75%      36.417710    -4.317095     2.360000     2.320000    36.417780
# max      37.547860    -3.779490    30.150000    22.320000    37.548280
#
#             DEpeak         Sint       e_Sint        Speak      e_Speak  \
# count  5762.000000  5762.000000  5762.000000  5762.000000  5762.000000
# mean     -4.702614     1.115438     0.006843     0.761205     0.006246
# std       0.461173    10.169679     0.006504     6.953952     0.004331
# ...

# %%
print(df.isnull().sum())
# Out:
# ID              0
# RAdeg           0
# DEdeg           0
# e_RAdeg         0
# e_DEdeg         0
# RApeak          0
# DEpeak          0
# Sint            0
# e_Sint          0
# Speak           0
# e_Speak         0
# rmspeak         0
# e_rmspeak       0
# thetamaj        0
# thetamin        0
# PA              0
# alpha        2304
# e_alpha      2304
# ID2          5732
# ID3          5750
# dtype: int64

# %%
# Drop columns if they don’t vary or are redundant (example: ID2, ID3)
df = df.drop(['ID2', 'ID3'], axis=1)

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['RAdeg'], df['DEdeg'], s=2, color='k')
plt.xlabel('Right Ascension (deg)')
plt.ylabel('Declination (deg)')
plt.title('Sky Map of VLA XMM-LSS/VIDEO Deep Field Radio Sources')
plt.gca().invert_xaxis()  # Astronomers plot RA decreasing to the right
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['RAdeg'], df['DEdeg'], 
            s=3, 
            c=df['Sint'], 
            cmap='plasma', 
            norm=plt.Normalize(vmin=df['Sint'].min(), vmax=df['Sint'].max()))
plt.xlabel('Right Ascension (deg)')
plt.ylabel('Declination (deg)')
plt.title('Sky Map (source brightness = color)')
plt.gca().invert_xaxis()
plt.grid(True)
plt.colorbar(label='Integrated Flux Density (mJy)')
plt.tight_layout()
plt.show()

# %%
df1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df1.info()
#
# NameError: name 'df1' is not defined

# %%
sns.histplot(df1['alpha'], bins=50, kde=True)
plt.title("Distribution of Alpha")
plt.xlabel("Alpha")
plt.ylabel("Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sns.histplot(df1['alpha'], bins=50, kde=True)
#       2 plt.title("Distribution of Alpha")
#       3 plt.xlabel("Alpha")
#
# NameError: name 'df1' is not defined

# %%
sns.histplot(df1['e_alpha'], bins=50, kde=True)
plt.title("Distribution of E-Alpha")
plt.xlabel("Alpha")
plt.ylabel("Count")
plt.show()

# %%
df.to_csv("../data/data.csv", index=False)

# %%
df_cleaned = df.drop(columns=['alpha', 'e_alpha'])

# %%
df_cleaned.isnull().sum()
# Out:
# ID           0
# RAdeg        0
# DEdeg        0
# e_RAdeg      0
# e_DEdeg      0
# RApeak       0
# DEpeak       0
# Sint         0
# e_Sint       0
# Speak        0
# e_Speak      0
# rmspeak      0
# e_rmspeak    0
# thetamaj     0
# thetamin     0
# PA           0
# dtype: int64

# %%
df_cleaned.to_csv('../data/noalpha.csv')
